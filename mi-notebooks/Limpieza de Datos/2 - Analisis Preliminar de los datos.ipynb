# %% [markdown]
# ## Resumen de los datos: dimensiones y estructuras

# %% [markdown]
# ### Importar librerias

# %%
import pandas as pd
import os

# %%
data = pd.read_csv("C:/Users/Nicolas/Documents/Coderhouse/datasets/titanic/titanic3.csv")
data.head(5) # para ver los datos que se carguen bien. primeros
data.tail() # "" .ultimos
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data.shape # la forma, no es una funcion, es una propiedad
# Out:
# (1309, 14)

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# Vamos hacer un resumen de los estadísticos básicos de las variables numéricas.

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# ## Missing Values (Faltante de datos)

# %%
#Comprobar 
pd.notnull(data["fare"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1304    True
# 1305    True
# 1306    True
# 1307    True
# 1308    True
# Name: fare, Length: 1309, dtype: bool

# %%
pd.notnull(data["fare"]).values.ravel().sum()
# Out:
# 1308

# %%
data.isnull().any()
# Out:
# pclass       False
# survived     False
# name         False
# sex          False
# age           True
# sibsp        False
# parch        False
# ticket       False
# fare          True
# cabin         True
# embarked      True
# boat          True
# body          True
# home.dest     True
# dtype: bool

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data["fare"] = data["fare"].fillna(151.5500)

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1309.000000  121.000000
# mean     33.385819  160.809917
# std      51.842016   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1309.000000  121.000000
# mean     33.385819  160.809917
# std      51.842016   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
pd.isnull(data["age"]).values.ravel().sum()
# Out:
# 263

# %%
da data["age"].fillna(data["age"].mean())
# Out:
#   File "<ipython-input-143-eaafc4a0a68b>", line 1
#     da data["age"].fillna(data["age"].mean())
#        ^
# SyntaxError: invalid syntax

# %%
data["age"] = data["age"].fillna(data["age"].mean()).round()
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.896868     0.498854     0.385027
# std       0.837836     0.486055    12.881579     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000    22.000000     0.000000     0.000000
# 50%       3.000000     0.000000    30.000000     0.000000     0.000000
# 75%       3.000000     1.000000    35.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1309.000000  121.000000
# mean     33.385819  160.809917
# std      51.842016   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data["body"] = data["body"].fillna(data["body"].mean())

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.896868     0.498854     0.385027
# std       0.837836     0.486055    12.881579     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000    22.000000     0.000000     0.000000
# 50%       3.000000     0.000000    30.000000     0.000000     0.000000
# 75%       3.000000     1.000000    35.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare         body
# count  1309.000000  1309.000000
# mean     33.385819   160.809917
# std      51.842016    29.591544
# min       0.000000     1.000000
# 25%       7.895800   160.809917
# 50%      14.454200   160.809917
# 75%      31.275000   160.809917
# max     512.329200   328.000000

# %% [markdown]
# ### Dummy

# %%
pd.get_dummies?
data["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
dummy_sex = pd.get_dummies(data["sex"])

# %%
dummy_sex
# Out:
#       female  male
# 0          1     0
# 1          0     1
# 2          1     0
# 3          0     1
# 4          1     0
# ...      ...   ...
# 1304       1     0
# 1305       1     0
# 1306       0     1
# 1307       0     1
# 1308       0     1
#
# [1309 rows x 2 columns]
