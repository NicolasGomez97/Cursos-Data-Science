# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
mainpath = "/Users/Nicolas/Documents/DataScience/dataset/"
filename = "Summer-Olympic-medals-1976-to-2008.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath,encoding="latin")
data
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
data2 = pd.read_csv("C:/Users/Nicolas/Documents/DataScience/dataset/Summer-Olympic-medals-1976-to-2008.csv",encoding="latin")
data2
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
data2.tail()
# Out:
#           City    Year      Sport       Discipline       Event  \
# 15428  Beijing  2008.0  Wrestling  Wrestling Gre-R   66 - 74kg
# 15429  Beijing  2008.0  Wrestling  Wrestling Gre-R   66 - 74kg
# 15430  Beijing  2008.0  Wrestling  Wrestling Gre-R   55 - 60kg
# 15431  Beijing  2008.0  Wrestling  Wrestling Gre-R   60 - 66kg
# 15432  Beijing  2008.0  Wrestling  Wrestling Gre-R  96 - 120kg
#
#                    Athlete Gender Country_Code     Country Event_gender  \
# 15428   GUENOT, Christophe    Men          FRA      France            M
# 15429  KVIRKELIA, Manuchar    Men          GEO     Georgia            M
# 15430     RAHIMOV, Vitaliy    Men          AZE  Azerbaijan            M
# 15431       GUENOT, Steeve    Men          FRA      France            M
# 15432        LOPEZ, Mijain    Men          CUB        Cuba            M
#
#         Medal
# 15428  Bronze
# 15429    Gold
# 15430  Silver
# 15431    Gold
# 15432    Gold

# %%
data2.shape
# Out:
# (15433, 11)

# %%
data2.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
data2.describe()
# Out:
#                Year
# count  15316.000000
# mean    1993.620789
# std       10.159851
# min     1976.000000
# 25%     1984.000000
# 50%     1996.000000
# 75%     2004.000000
# max     2008.000000

# %%
data2.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Event            object
# Athlete          object
# Gender           object
# Country_Code     object
# Country          object
# Event_gender     object
# Medal            object
# dtype: object

# %% [markdown]
# # Importamos datos

# %%
data_bit = pd.read_csv("C:/Users/Nicolas/Documents/DataScience/dataset/gemini_BTCUSD_day.csv")
data_bit
# Out:
#       Unix Timestamp                 Date  Symbol      Open      High  \
# 0      1632110400000  2021-09-20 04:00:00  BTCUSD  45553.62  45837.90
# 1      1632024000000  2021-09-19 04:00:00  BTCUSD  47854.23  48333.32
# 2      1631937600000  2021-09-18 04:00:00  BTCUSD  47962.79  48808.97
# 3      1631851200000  2021-09-17 04:00:00  BTCUSD  47907.00  48165.96
# 4      1631764800000  2021-09-16 04:00:00  BTCUSD  47629.10  48500.00
# ...              ...                  ...     ...       ...       ...
# 2170      1444622400  2015-10-12 04:00:00  BTCUSD    248.98    248.98
# 2171      1444536000  2015-10-11 04:00:00  BTCUSD    246.30    249.50
# 2172      1444449600  2015-10-10 04:00:00  BTCUSD    245.51    246.30
# 2173      1444363200  2015-10-09 04:00:00  BTCUSD    243.60    249.97
# 2174      1444276800  2015-10-08 04:00:00  BTCUSD      0.00    245.00
#
#            Low     Close       Volume
# 0     42500.00  42602.79  3158.164133
# 1     45175.20  45553.62   860.712331
# ...

# %% [markdown]
# # Limpieza y Ordenamiento datos

# %%
data_bit = data_bit.drop(['Unix Timestamp'],axis=1)

# %%
data_bit
# Out:
#                      Date  Symbol      Open      High       Low     Close  \
# 0     2021-09-20 04:00:00  BTCUSD  45553.62  45837.90  42500.00  42602.79
# 1     2021-09-19 04:00:00  BTCUSD  47854.23  48333.32  45175.20  45553.62
# 2     2021-09-18 04:00:00  BTCUSD  47962.79  48808.97  47613.93  47854.23
# 3     2021-09-17 04:00:00  BTCUSD  47907.00  48165.96  46754.93  47962.79
# 4     2021-09-16 04:00:00  BTCUSD  47629.10  48500.00  47041.24  47907.00
# ...                   ...     ...       ...       ...       ...       ...
# 2170  2015-10-12 04:00:00  BTCUSD    248.98    248.98    245.75    245.75
# 2171  2015-10-11 04:00:00  BTCUSD    246.30    249.50    245.96    248.98
# 2172  2015-10-10 04:00:00  BTCUSD    245.51    246.30    244.60    246.30
# 2173  2015-10-09 04:00:00  BTCUSD    243.60    249.97    243.60    245.51
# 2174  2015-10-08 04:00:00  BTCUSD      0.00    245.00      0.00    243.60
#
#            Volume
# 0     3158.164133
# 1      860.712331
# 2      671.356150
# ...

# %%
data_bit.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df_columns = data_bit.columns
df_columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
data_bit['Date'] = pd.to_datetime(data_bit['Date'],format='%Y-%m-%d')
df_index = data_bit['Date'].dt.date

# %%
df_index
# Out:
# 0       2021-09-20
# 1       2021-09-19
# 2       2021-09-18
# 3       2021-09-17
# 4       2021-09-16
#            ...
# 2170    2015-10-12
# 2171    2015-10-11
# 2172    2015-10-10
# 2173    2015-10-09
# 2174    2015-10-08
# Name: Date, Length: 2175, dtype: object

# %%
df_valores = data_bit.values[:,:]
df_valores
# Out:
# array([[Timestamp('2021-09-20 04:00:00'), 'BTCUSD', 45553.62, ...,
#         42500.0, 42602.79, 3158.164133009],
#        [Timestamp('2021-09-19 04:00:00'), 'BTCUSD', 47854.23, ...,
#         45175.2, 45553.62, 860.7123305230999],
#        [Timestamp('2021-09-18 04:00:00'), 'BTCUSD', 47962.79, ...,
#         47613.93, 47854.23, 671.3561498764],
#        ...,
#        [Timestamp('2015-10-10 04:00:00'), 'BTCUSD', 245.51, ..., 244.6,
#         246.3, 30.8705493027],
#        [Timestamp('2015-10-09 04:00:00'), 'BTCUSD', 243.6, ..., 243.6,
#         245.51, 61.5870675401],
#        [Timestamp('2015-10-08 04:00:00'), 'BTCUSD', 0.0, ..., 0.0, 243.6,
#         34.7547026012]], dtype=object)

# %%
data_bit = pd.DataFrame(df_valores,index=df_index,columns=df_columns)
data_bit = data_bit.drop(['Date'],axis=1)

# %%
data_bit
# Out:
#             Symbol     Open     High      Low    Close   Volume
# Date
# 2021-09-20  BTCUSD  45553.6  45837.9    42500  42602.8  3158.16
# 2021-09-19  BTCUSD  47854.2  48333.3  45175.2  45553.6  860.712
# 2021-09-18  BTCUSD  47962.8    48809  47613.9  47854.2  671.356
# 2021-09-17  BTCUSD    47907    48166  46754.9  47962.8  1247.38
# 2021-09-16  BTCUSD  47629.1    48500  47041.2    47907  1069.57
# ...            ...      ...      ...      ...      ...      ...
# 2015-10-12  BTCUSD   248.98   248.98   245.75   245.75  71.0477
# 2015-10-11  BTCUSD    246.3    249.5   245.96   248.98  22.7471
# 2015-10-10  BTCUSD   245.51    246.3    244.6    246.3  30.8705
# 2015-10-09  BTCUSD    243.6   249.97    243.6   245.51  61.5871
# 2015-10-08  BTCUSD        0      245        0    243.6  34.7547
#
# [2175 rows x 6 columns]

# %%
data_bit2=data_bit.head?

# %%
data_bit2=data_bit.tail?

# %%
data_bit2=data_bit[20:35]
data_bit2 = data_bit2.iloc[::-1]
data_bit2
# Out:
#             Symbol     Open     High      Low    Close   Volume
# Date
# 2021-08-17  BTCUSD  46435.4  47162.9  44211.1  45078.8  2149.38
# 2021-08-18  BTCUSD  45078.8    46031    44055  44074.8  1324.73
# 2021-08-19  BTCUSD  44074.8  47424.1  43902.5  47042.3     1566
# 2021-08-20  BTCUSD  47042.3    49400  46714.6  48839.6  1328.32
# 2021-08-21  BTCUSD  48839.6  49812.5  48281.4  48837.6  1213.11
# 2021-08-22  BTCUSD  48837.6  50540.2    48071  50289.1  974.812
# 2021-08-23  BTCUSD  50289.1    50518    48800    49350  1051.66
# 2021-08-24  BTCUSD    49350  49867.7  47614.3  47995.8  1369.87
# 2021-08-25  BTCUSD  47995.8  49365.4  47112.1    47931  1666.41
# 2021-08-26  BTCUSD    47931  48053.1  46287.6  46845.9     2205
# 2021-08-27  BTCUSD  46845.9  49313.3  46603.4    48900  1383.21
# 2021-08-28  BTCUSD    48900    49650    48108  48267.2  544.262
# 2021-08-29  BTCUSD  48267.2  49408.1    47800  47989.6  446.769
# 2021-08-30  BTCUSD  47989.6  48735.7  46717.2  47151.9   933.28
# ...

# %%
x=data_bit2.index
y=data_bit2["Open"]
y
# Out:
# Date
# 2021-08-17    46435.4
# 2021-08-18    45078.8
# 2021-08-19    44074.8
# 2021-08-20    47042.3
# 2021-08-21    48839.6
# 2021-08-22    48837.6
# 2021-08-23    50289.1
# 2021-08-24      49350
# 2021-08-25    47995.8
# 2021-08-26      47931
# 2021-08-27    46845.9
# 2021-08-28      48900
# 2021-08-29    48267.2
# 2021-08-30    47989.6
# 2021-08-31    47151.9
# Name: Open, dtype: object

# %%
fig, ax = plt.subplots(figsize=(17,4))
ax.plot(x,y,label='Rango de bitcoins del mes ago')
ax.set_xlabel('Año')
ax.set_ylabel('Valor USD')
ax
ax.set_xlim(data_bit2.index[0], data_bit2.index[-1])
# Out:
# (18856.0, 18870.0)
