# %% [markdown]
# ## Funciones de distribución de probabilidades
# #### Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=1
b=100
n=200000
data = np.random.uniform(a,b,n)

# %%
data
# Out:
# array([76.8695953 , 83.77462739, 88.07745623, ..., 40.9481664 ,
#        11.06994515, 12.72793402])

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([19979., 19976., 20138., 20059., 19946., 19964., 19806., 20022.,
#         20034., 20076.]),
#  array([ 1.00015747, 10.90012974, 20.800102  , 30.70007427, 40.60004654,
#         50.50001881, 60.39999107, 70.29996334, 80.19993561, 90.09990787,
#         99.99988014]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## La campana de gauss (Normal)

# %%
data = np.random.randn?

# %%
data = np.random.randn(1000000)
data

# %%
x = range(0,1000000)

# %%
plt.hist(data)
# Out:
# (array([1.40000e+01, 6.77000e+02, 1.32380e+04, 9.80600e+04, 2.96945e+05,
#         3.66138e+05, 1.83832e+05, 3.79300e+04, 3.07400e+03, 9.20000e+01]),
#  array([-5.16004568, -4.17409453, -3.18814337, -2.20219222, -1.21624106,
#         -0.23028991,  0.75566125,  1.74161241,  2.72756356,  3.71351472,
#          4.69946587]),
#  <BarContainer object of 10 artists>)

# %%
# para verificar los datos
plt.plot(x,sorted(data))

# %%
# %matplotlib inline
mu = 5.5 
sd = 2.5 
data = 5.5 + 2.5*np.random.rand(10000)
plt.hist(data)
# Out:
# (array([ 991., 1009.,  997.,  996., 1008., 1074.,  999., 1014.,  921.,
#          991.]),
#  array([5.50017548, 5.75013306, 6.00009065, 6.25004823, 6.50000581,
#         6.74996339, 6.99992098, 7.24987856, 7.49983614, 7.74979373,
#         7.99975131]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### la simulación de Monte Carlo

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# * Generamos dos números aleatorios x e y entre 0 y 1
# * Calcularemos x * x + y * y
#     * Si el valor es inferior a 1 -> estamos dentro del círculo
#     * Si el valor es superior a 1 -> estamos fuera del círculo
#
# * Calcular el numero total de veces que están dentro del círculo y lo dividimos entre el número total de intentos para obtener una aproximación de la probabilidad de caer dentro del círculo
# * Usamos dicha probabilidad para aproximar el valor de π.
# * Repetimos el experimento un número suficiente de veces, para obtener diferentes aproximaciones de π.
# * Calculamos el promedio de los 1000 experimentos anteriores para dar un valor final de π.

# %%
pi_avg = 0
n = 1000
pi_value_list = []
for i in range(100):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for j in range(n):
        z = np.sqrt(x[j] * x[j] + y[j] * y[j])
        if z <=1:
            value += 1
    float_value = float(value)
    pi_value = float_value * 4 / n
    pi_value_list.append(pi_value)
    pi_avg += pi_value

pi = pi_avg/100
print(pi)
plt.plot(pi_value_list)
# Out:
# 3.138880000000001

# %% [markdown]
# ### Dummy Data Sets

# %%
data = pd.DataFrame(
    {
        'A' : np.random.randn(10),
        'B' : 1.5 + 2.5 * np.random.randn(10),
        'C' : np.random.uniform(5,32,10)
    }
)

# %%
data.describe()
# Out:
#                A          B          C
# count  10.000000  10.000000  10.000000
# mean   -0.323369   1.354450  16.629373
# std     0.749050   2.109796   9.266301
# min    -1.099026  -2.749925   5.254062
# 25%    -0.830901   0.500536   8.177284
# 50%    -0.514433   1.255248  15.942254
# 75%    -0.021166   2.515072  23.917993
# max     1.437716   4.857550  30.768791

# %%
data = pd.read_csv("C:/Users/Nicolas/Documents/Coderhouse/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           3333 non-null   object
#  1   Account Length  3333 non-null   int64
#  2   Area Code       3333 non-null   int64
#  3   Phone           3333 non-null   object
#  4   Int'l Plan      3333 non-null   object
#  5   VMail Plan      3333 non-null   object
#  6   VMail Message   3333 non-null   int64
#  7   Day Mins        3333 non-null   float64
#  8   Day Calls       3333 non-null   int64
#  9   Day Charge      3333 non-null   float64
#  10  Eve Mins        3333 non-null   float64
#  11  Eve Calls       3333 non-null   int64
#  12  Eve Charge      3333 non-null   float64
#  13  Night Mins      3333 non-null   float64
#  14  Night Calls     3333 non-null   int64
#  15  Night Charge    3333 non-null   float64
#  16  Intl Mins       3333 non-null   float64
# ...

# %%
data.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
# Out:
# <bound method DataFrame.info of      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
columns_names = data.columns.values.tolist()

# %%
columns_names
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
columns_names
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
long_columns = len(columns_names)
long_columns
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name': columns_names,
        'A' : np.random.randn(long_columns),
        'B' : 1.5 + 2.5 * np.random.randn(long_columns),
        'C' : np.random.uniform(5,32,long_columns)
    }
)

# %%
new_data
# Out:
#        Column Name         A         B          C
# 0            State -1.441872  0.619062  18.234489
# 1   Account Length -0.130221  0.683444  18.894099
# 2        Area Code -0.424464  3.662440  22.752799
# 3            Phone  0.737106 -0.001156   5.077141
# 4       Int'l Plan -1.400343  0.776067  23.140187
# 5       VMail Plan  1.625013  2.507081  29.462756
# 6    VMail Message  0.348015  2.423151  28.203783
# 7         Day Mins  1.445756 -0.303645   6.600640
# 8        Day Calls -0.086433 -3.276746  25.070144
# 9       Day Charge -0.185907 -2.967166  21.931695
# 10        Eve Mins -0.574901  0.888037  11.669019
# 11       Eve Calls -0.155047  0.493019   9.274289
# 12      Eve Charge  1.308510  7.702415  30.105686
# 13      Night Mins -1.229972 -1.080143  22.117355
# 14     Night Calls -0.923089 -0.046883  29.105210
# 15    Night Charge  1.510976  2.928191   6.982804
# 16       Intl Mins -0.996002 -3.083829  17.102217
# 17      Intl Calls  0.509408 -3.005777  11.532656
# ...
