# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/analisismercadolibre (1).csv")

# %%
df.describe()
# Out:
#        web-scraper-order             web-scraper-start-url  \
# count                180                               180
# unique               180                                 1
# top       1604780605-373  https://www.mercadolibre.com.co/
# freq                   1                               180
#
#        Categoria_Electrodomesticos  \
# count                          180
# unique                           1
# top              Electrodomésticos
# freq                           180
#
#                          Categoria_Electrodomesticos-href  \
# count                                                 180
# unique                                                  1
# top     https://www.mercadolibre.com.co/c/electrodomes...
# freq                                                  180
#
#                      Refrigeradores  \
# count                           180
# unique                            1
# top     Refrigera-ciónVer productos
# freq                            180
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   web-scraper-order                 180 non-null    object
#  1   web-scraper-start-url             180 non-null    object
#  2   Categoria_Electrodomesticos       180 non-null    object
#  3   Categoria_Electrodomesticos-href  180 non-null    object
#  4   Refrigeradores                    180 non-null    object
#  5   Refrigeradores-href               180 non-null    object
#  6   Nombre_Producto                   180 non-null    object
#  7   Nombre_Producto-href              180 non-null    object
#  8   Precio                            71 non-null     object
#  9   Marca                             54 non-null     object
#  10  Foto_Nevera-src                   55 non-null     object
# dtypes: object(11)
# memory usage: 15.6+ KB

# %%
df
# Out:
#     web-scraper-order             web-scraper-start-url  \
# 0      1604780552-325  https://www.mercadolibre.com.co/
# 1      1604780449-235  https://www.mercadolibre.com.co/
# 2      1604780512-287  https://www.mercadolibre.com.co/
# 3      1604780531-305  https://www.mercadolibre.com.co/
# 4      1604780469-254  https://www.mercadolibre.com.co/
# ..                ...                               ...
# 175    1604780411-202  https://www.mercadolibre.com.co/
# 176    1604780576-349  https://www.mercadolibre.com.co/
# 177    1604780607-377  https://www.mercadolibre.com.co/
# 178    1604780417-210  https://www.mercadolibre.com.co/
# 179    1604780464-245  https://www.mercadolibre.com.co/
#
#     Categoria_Electrodomesticos  \
# 0             Electrodomésticos
# 1             Electrodomésticos
# 2             Electrodomésticos
# 3             Electrodomésticos
# 4             Electrodomésticos
# ..                          ...
# 175           Electrodomésticos
# ...

# %%
df_btc = pd.read_csv("../datasets/cryptomoneda/BTC-USD-2.csv")
df_btc

# %%
df_
# Out:
#            Date          Open          High           Low         Close  \
# 0    2020-06-16   9454.266602   9579.430664   9400.445313   9538.024414
# 1    2020-06-17   9533.784180   9540.422852   9327.339844   9480.254883
# 2    2020-06-18   9481.567383   9482.782227   9328.395508   9411.840820
# 3    2020-06-19   9410.293945   9440.875977   9274.295898   9288.018555
# 4    2020-06-20   9290.959961   9394.971680   9247.379883   9332.340820
# ..          ...           ...           ...           ...           ...
# 361  2021-06-12  37340.144531  37408.925781  34728.191406  35552.515625
# 362  2021-06-13  35555.789063  39322.781250  34864.109375  39097.859375
# 363  2021-06-14  39016.968750  40978.363281  38757.285156  40536.070313
# 364  2021-06-15  40526.781250  41295.269531  39609.468750  40155.296875
# 365  2021-06-16  40023.757813  40472.218750  38562.894531  38692.386719
#
#         Adj Close        Volume
# 0     9538.024414  2.156554e+10
# 1     9480.254883  2.017771e+10
# ...

# %%
df_finance = pd.read_csv("../datasets/Finance_data.csv")

# %%
df_finance
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df_finance.shape
# Out:
# (40, 24)

# %%
df_finance_ori = pd.read_csv("../datasets/Original_data.csv")

# %%
df_finance_ori.shape
# Out:
# (40, 24)

# %%
df_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df = pd.read_csv("../datasets/WIKI-AAPL.csv")

# %%
df
# Out:
#             Date    Open    High     Low    Close      Volume  Ex-Dividend  \
# 0     2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
# 1     2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2     2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 3     2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 4     2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# ...          ...     ...     ...     ...      ...         ...          ...
# 9395  1980-12-18   26.63   26.75   26.63   26.630    327900.0          0.0
# 9396  1980-12-17   25.87   26.00   25.87   25.870    385900.0          0.0
# 9397  1980-12-16   25.37   25.37   25.25   25.250    472000.0          0.0
# 9398  1980-12-15   27.38   27.38   27.25   27.250    785200.0          0.0
# 9399  1980-12-12   28.75   28.87   28.75   28.750   2093900.0          0.0
#
# ...

# %%
data_bitcoins = pd.read_csv('../datasets/cryptomoneda/coin_Bitcoin.csv')

# %%
data_bitcoins
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...
