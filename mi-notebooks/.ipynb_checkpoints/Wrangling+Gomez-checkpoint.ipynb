# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importamos Datasets
w_data = pd.read_csv('../datasets/w_data.csv',sep=';')
p_data = pd.read_csv('../datasets/p_data.csv',sep=';')

# %%
w_data.shape
w_data
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target
# 0                40.0       49084    <=50K
# 1                13.0       68553    <=50K
# 2                40.0      143654    <=50K
# ...

# %%
p_data
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
p_data.shape
p_data
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
data = pd.merge(w_data,p_data,on='ID',how='left')
data
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target   Age      Sex  \
# 0                40.0       49084    <=50K  39.0     Male
# 1                13.0       68553    <=50K  50.0     Male
# ...

# %%
data.sort_values("ID", inplace=True)
p_data.sort_values("ID", inplace=True)

# %%
#Cantidad de datos que coinciden
print("Cantidad de datos que coinciden con el otro dataset "+str(len(data[data.ID.isin(p_data.ID)])))
# Out:
# Cantidad de datos que coinciden con el otro dataset 48842

# %%
t = pd.concat([w_data.ID,p_data.ID], axis=0)
t
# Out:
# 0             49084
# 1             68553
# 2            143654
# 3             41510
# 4            195025
#             ...
# 32175    3199610067
# 32255    3200552514
# 32011    3200755724
# 32547    3225489111
# 32542    3229272340
# Name: ID, Length: 97685, dtype: int64

# %%
len(w_data.ID) + len(p_data.ID)
# Out:
# 97685

# %%
#El valor que da True es el unico valor que no se repite en los DataFrame
t.value_counts() == 1
# Out:
# 2913601535    False
# 787194849     False
# 862736664     False
# 326724600     False
# 164810680     False
#               ...
# 686046829     False
# 155072108     False
# 33818218      False
# 511184898     False
# 1344995623     True
# Name: ID, Length: 48843, dtype: bool

# %%
data[data["ID"] == 1344995623]
# Out:
#            Workclass    fnlwgt  Capital Gain  Capital Loss  Hours per week  \
# 48842   Self-emp-inc  182148.0           0.0           0.0            60.0
#
#                ID  Target  Age  Sex Race Country Education  Education-Num  \
# 48842  1344995623   >50K.  NaN  NaN  NaN     NaN       NaN            NaN
#
#       Marital Status Relationship
# 48842            NaN          NaN

# %%
# Actividad 2.
data["Target"].value_counts()
# Out:
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3846
# Name: Target, dtype: int64

# %%
data["Target"]=data["Target"].str.replace('<=50K.','<=50K')
data["Target"].value_counts()
# Out:
#  <=50K    37155
#  >50K      7841
#  >50K.     3846
# Name: Target, dtype: int64

# %%
data["Target"]=data["Target"].str.replace('>50K.','>50K')
data["Target"].value_counts()
# Out:
#  <=50K    37155
#  >50K     11687
# Name: Target, dtype: int64

# %%
data["Target"]
# Out:
# 39866      >50K
# 501       <=50K
# 8          >50K
# 37823     <=50K
# 8733      <=50K
#           ...
# 32175     <=50K
# 32255     <=50K
# 32011     <=50K
# 32547     <=50K
# 32542     <=50K
# Name: Target, Length: 48843, dtype: object

# %%
data.sort_values("Target", inplace= True)

# %%
data2 = data[data["Target"].isin(['>50K'])]

# %%
data2
# Out:
# Empty DataFrame
# Columns: [Workclass, fnlwgt, Capital Gain, Capital Loss, Hours per week, ID, Target, Age, Sex, Race, Country, Education, Education-Num, Marital Status, Relationship]
# Index: []

# %%
(data['Target']=='>50K')
# Out:
# 9390     False
# 40289    False
# 47808    False
# 43273    False
# 45158    False
#          ...
# 2385     False
# 28261    False
# 12429    False
# 39866    False
# 32561    False
# Name: Target, Length: 48843, dtype: bool

# %%
data = data.dropna()
data
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 9390             Private  135470.0           0.0           0.0
# 40289   Self-emp-not-inc  386773.0           0.0           0.0
# 47808            Private  181353.0           0.0           0.0
# 43273            Private   87520.0           0.0           0.0
# 45158          Local-gov  317846.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 41193          Local-gov  316470.0           0.0           0.0
# 2385        Self-emp-inc  211804.0       15024.0           0.0
# 28261   Self-emp-not-inc  315984.0        7688.0           0.0
# 12429            Private   81654.0           0.0           0.0
# 39866            Private  305319.0           0.0           0.0
#
#        Hours per week         ID  Target   Age      Sex    Race  \
# 9390             40.0  471446074   <=50K  60.0     Male   White
# 40289            60.0  687955542   <=50K  54.0     Male   White
# ...

# %%
#2
# Filtramos >50K
data3= data[data["Target"].str.contains('>50K')]

# %%
data3
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 29157            Private  207202.0           0.0           0.0
# 28264   Self-emp-not-inc  120781.0       99999.0           0.0
# 31412            Private  177087.0           0.0           0.0
# 48702            Private   97723.0           0.0           0.0
# 24018   Self-emp-not-inc  104501.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 41193          Local-gov  316470.0           0.0           0.0
# 2385        Self-emp-inc  211804.0       15024.0           0.0
# 28261   Self-emp-not-inc  315984.0        7688.0           0.0
# 12429            Private   81654.0           0.0           0.0
# 39866            Private  305319.0           0.0           0.0
#
#        Hours per week          ID Target   Age      Sex    Race  \
# 29157            48.0  1728571847   >50K  38.0     Male   White
# 28264            70.0  1784179578   >50K  51.0     Male   Other
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11686 entries, 29157 to 39866
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Workclass       11686 non-null  object
#  1   fnlwgt          11686 non-null  float64
#  2   Capital Gain    11686 non-null  float64
#  3   Capital Loss    11686 non-null  float64
#  4   Hours per week  11686 non-null  float64
#  5   ID              11686 non-null  int64
#  6   Target          11686 non-null  object
#  7   Age             11686 non-null  float64
#  8   Sex             11686 non-null  object
#  9   Race            11686 non-null  object
#  10  Country         11686 non-null  object
#  11  Education       11686 non-null  object
#  12  Education-Num   11686 non-null  float64
#  13  Marital Status  11686 non-null  object
#  14  Relationship    11686 non-null  object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
# Porcentaje entre Sexo y target a >50K
df_sex = data3.groupby(['Sex','Target'])['Sex'].count()/len(data3['Target'])*100

# %%
df_sex
# Out:
# Sex      Target
#  Female   >50K     15.137772
#  Male     >50K     84.862228
# Name: Sex, dtype: float64

# %%
plt.pie(df_sex, labels=df_sex.index)
plt.axis("equal")
plt.show()

# %%
# Porcentaje entre Raza y target a >50K
df_race = data3.groupby(['Race','Target'])['Race'].count()/len(data3['Target'])*100

# %%
df_race
# Out:
# Race                 Target
#  Amer-Indian-Eskimo   >50K      0.470649
#  Asian-Pac-Islander   >50K      3.499914
#  Black                >50K      4.843402
#  Other                >50K      0.427862
#  White                >50K     90.758172
# Name: Race, dtype: float64

# %%
#Grafico
plt.pie(df_race, labels=df_race.index)
plt.axis("equal")
plt.show()

# %%
# Porcentaje entre Raza y target a >50K
df_education = data3.groupby(['Education','Target'])['Education'].count()/len(data3['Target'])*100

# %%
df_education
# Out:
# Education      Target
#  10th           >50K      0.744481
#  11th           >50K      0.787267
#  12th           >50K      0.410748
#  1st-4th        >50K      0.068458
#  5th-6th        >50K      0.231046
#  7th-8th        >50K      0.530549
#  9th            >50K      0.350847
#  Assoc-acdm     >50K      3.534143
#  Assoc-voc      >50K      4.466883
#  Bachelors      >50K     28.341605
#  Doctorate      >50K      3.688174
#  HS-grad        >50K     21.418792
#  Masters        >50K     12.485025
#  Preschool      >50K      0.008557
#  Prof-school    >50K      5.279822
#  Some-college   >50K     17.653603
# Name: Education, dtype: float64

# %%
#Grafico
plt.pie(df_education, labels=df_education.index)
plt.axis("equal")
plt.show()
