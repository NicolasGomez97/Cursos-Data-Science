# %%
# Importamos librerias
import pandas as pd

# %%
# Leemos JSON por la URL
data = pd.read_json("https://jsonplaceholder.typicode.com/users")

# %%
# Ver parametros que se pueden usar con el pd.read_json
pd.read_json?

# %%
# Verificamos que el DataFrame
data
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %% [markdown]
# # ANÁLISIS UNIVARIADO DEL PROYECTO

# %%
# Importamos librerias
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# ### 1. IMPORTACION Y CARGA DE DATOS

# %%
#importamos csv 
data = pd.read_csv("../datasets/bank/bank.csv",sep=';')

# %% [markdown]
# ### 2. ANALISIS EXPLORATORIO

# %%
data.shape
# Out:
# (4119, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
data.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
data.head(5)
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %% [markdown]
# Resumen de datos:
#
# Los datos son relacionados sobre el bank que ven potenciale clientes que puedan invertir en acciones. Son 21Columanas donde la columna "y" Si el cliente se ha suscrito un depósito a plazo(binario: "sí", "no")
#
# * No hay datos nullos

# %% [markdown]
# ### 3. CREACIÓN DE VARIABLES

# %%
#los que tienen invertido en plazo fijo 
data_p = data[data["y"].isin(['yes'])]

# %%
data_p
# Out:
#       age          job   marital            education default housing loan  \
# 19     50  blue-collar   married             basic.4y      no      no  yes
# 21     39   technician  divorced          high.school      no      no   no
# 25     38   technician   married  professional.course      no     yes   no
# 53     24   technician   married    university.degree      no     yes  yes
# 59     60       admin.  divorced  professional.course      no     yes   no
# ...   ...          ...       ...                  ...     ...     ...  ...
# 4034   74      retired   married    university.degree      no     yes  yes
# 4066   81      retired   married             basic.4y      no     yes   no
# 4069   60       admin.   married    university.degree      no     yes   no
# 4088   47   management   married    university.degree      no     yes   no
# 4089   25       admin.    single    university.degree      no     yes  yes
#
# ...

# %%
data_age = data_p["age"]

# %%
data_age
# Out:
# 19      50
# 21      39
# 25      38
# 53      24
# 59      60
#         ..
# 4034    74
# 4066    81
# 4069    60
# 4088    47
# 4089    25
# Name: age, Length: 451, dtype: int64

# %%
data_edu = data_p["education"].value_counts()

# %%
data_edu
# Out:
# university.degree      165
# high.school             97
# professional.course     65
# basic.9y                43
# basic.4y                38
# unknown                 26
# basic.6y                17
# Name: education, dtype: int64

# %%
data_plazo = data["y"].value_counts()

# %%
data_plazo
# Out:
# no     3668
# yes     451
# Name: y, dtype: int64

# %% [markdown]
# ### 4. ANALISIS

# %%
from seaborn import boxplot
boxplot(data_age)
# Out:
# C:\Users\Nicolas\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# Le edad que mas invierten es entre 35 y 40.

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.hist(data_p["education"])
# Out:
# (array([ 38.,  97.,   0.,  65.,   0., 165.,  26.,   0.,  43.,  17.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Los principales inversionitas estan cursando la universidad.

# %%
#Grafico
plt.pie(data_plazo, labels=['No','Yes'])
plt.axis("equal")
plt.show()

# %% [markdown]
# Persona que ivirtieron que van ivirtiendo hasta ahora.
