# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Credit Analysis With KNN/DTree/RF /Bagging🏦</p>
#
# <img src="https://i1.wp.com/dataaspirant.com/wp-content/uploads/2020/09/1-Credit-card-fraud-detection-with-classification-algorithms.png?w=750&ssl=1">
#
#
# <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Table Of Contents</p>
#
# * [1. Importing Modules](#1)
#
# * [2. Loading Data](#2)
#
# * [3. Data PreProcessing And Visualizations](#3)
#
# * [4. Utility Functions](#4)
#
# * [5. Data Balancing](#5)
#
# * [6. Modelling And Optimizing The Models](#6)
#
# * [7. Results And Conclusion](#7)

# %% [markdown]
# <a id="1"></a>
#
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Importing Modules</p>

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd 
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix,r2_score
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
import warnings
from imblearn.over_sampling import SMOTE
warnings.filterwarnings('ignore')
import tensorflow as tf
from tensorflow import keras 
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
# Out:
# 2021-12-30 11:33:03.096970: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
tf.test.gpu_device_name()
# Out:
# 2021-12-30 11:33:07.137242: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# '/device:GPU:0'
# 2021-12-30 11:33:07.139926: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-30 11:33:07.142812: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-30 11:33:07.190475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:07.191148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-12-30 11:33:07.191214: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-30 11:33:07.216694: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-30 11:33:07.216785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-30 11:33:07.231803: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-30 11:33:07.240093: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-30 11:33:07.267779: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-30 11:33:07.274843: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-30 11:33:07.278316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-30 11:33:07.278506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:07.279248: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:07.280740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-30 11:33:07.281784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-30 11:33:08.697296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-30 11:33:08.697345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-12-30 11:33:08.697355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-12-30 11:33:08.699748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:08.700547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:08.701239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 11:33:08.701802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)

# %% [markdown]
# <a id = "2"></a>
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Loading Data</p>

# %%
df = pd.read_csv('/kaggle/input/bank-marketing/bank-additional-full.csv', sep = ';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Checking For Categorical Columns</p>

# %%
for col in df.columns:
    print()
    if df[col].dtype == 'object':
        print(f'Name of Column is: {col} and unique values are: {df[col].unique()}')
# Out:
# Name of Column is: job and unique values are: ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
#
# Name of Column is: marital and unique values are: ['married' 'single' 'divorced' 'unknown']
#
# Name of Column is: education and unique values are: ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
#
# Name of Column is: default and unique values are: ['no' 'unknown' 'yes']
#
# Name of Column is: housing and unique values are: ['no' 'yes' 'unknown']
#
# Name of Column is: loan and unique values are: ['no' 'yes' 'unknown']
#
# Name of Column is: contact and unique values are: ['telephone' 'cellular']
#
# Name of Column is: month and unique values are: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
#
# Name of Column is: day_of_week and unique values are: ['mon' 'tue' 'wed' 'thu' 'fri']
#
#
#
#
#
# Name of Column is: poutcome and unique values are: ['nonexistent' 'failure' 'success']
#
#
#
#
#
#
# Name of Column is: y and unique values are: ['no' 'yes']

# %% [markdown]
# <a id = "4"></a>
#
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Utility Functions</p>

# %%
#this function returns categorical variables
def return_categorical(df):

  categorical_columns = [column_name for column_name in df if df[column_name].dtype == 'O']
  return categorical_columns

#this function returns numerical variables
def return_numerical(df):

  return list(set(df.columns) - set(return_categorical(df)))


def check_normal(df):
  fig, axes = plt.subplots(1,len(return_numerical(df)), figsize =(70, 10))

  for i,numeric_column_name in enumerate(list(set(df.columns) -set(return_categorical(df)))):

    sns.distplot(df[numeric_column_name], ax=axes[i]);
    plt.title(f'Distribution of {numeric_column_name}');
    
def classifier(clf, x_train,x_test,y_train,y_test):
    y_test_pred = clf.predict(x_test)
    y_train_pred = clf.predict(x_train)

    accuracy_test = accuracy_score(y_test,y_test_pred)
    accuracy_train =  accuracy_score(y_train,y_train_pred)
    
    roc_test = roc_auc_score(y_test, y_test_pred, multi_class='ovr')
    roc_train = roc_auc_score(y_train, y_train_pred, multi_class='ovr')
    
    print('Train accuracy is:',accuracy_train )
    print('Test accuracy is:',accuracy_test )
    print()
    print('Train ROC is:', roc_train)
    print('Test ROC is:',roc_test )
    
    # Fscore, precision and recall on test data
    f1 = f1_score(y_test, y_test_pred)
    precision = precision_score(y_test, y_test_pred)
    recall = recall_score(y_test, y_test_pred) 
    print()
    print("F score is:",f1 )
    print("Precision is:",precision)
    print("Recall is:", recall)
  

def random_search(clf,params, x_train,x_test,y_train,y_test):
    
    random_search = RandomizedSearchCV(estimator= clf, param_distributions=params, scoring='roc_auc', cv=5)
    random_search.fit(x_train, y_train)
    optimal_model = random_search.best_estimator_

    print("Best parameters are: ", random_search.best_params_)
    print()
    print("Best estimator is: ", random_search.best_estimator_)
    print()
    print('Scores and accuracies are:')
    print()
    classifier(optimal_model, x_train,x_test,y_train,y_test)

# %% [markdown]
# <a id= "3"></a>
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Data PreProcessing And Visualizations</p>

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Checking Distribution For Continuous Variables</p>

# %%
check_normal(df)

# %% [markdown]
# > **None of the features are following a normal distribution**

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Plots For Categorical Variables</p>

# %%
# plotting graphs for all categorical columns
for col in return_categorical(df):
    counts = df[col].value_counts().sort_index()
    if len(counts) > 10:
      fig = plt.figure(figsize=(30, 10))
    else:
      fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col) 
    ax.set_ylabel("Frequency")
plt.show()

# %% [markdown]
# > **Class imbalance observed for target variable**

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Checking For Highly Correlated Columns</p>

# %%
corr = df.corr()
corr_greater_than_75 = corr[corr>=.75]
corr_greater_than_75
# Out:
#                 age  duration  campaign  pdays  previous  emp.var.rate  \
# age             1.0       NaN       NaN    NaN       NaN           NaN
# duration        NaN       1.0       NaN    NaN       NaN           NaN
# campaign        NaN       NaN       1.0    NaN       NaN           NaN
# pdays           NaN       NaN       NaN    1.0       NaN           NaN
# previous        NaN       NaN       NaN    NaN       1.0           NaN
# emp.var.rate    NaN       NaN       NaN    NaN       NaN      1.000000
# cons.price.idx  NaN       NaN       NaN    NaN       NaN      0.775334
# cons.conf.idx   NaN       NaN       NaN    NaN       NaN           NaN
# euribor3m       NaN       NaN       NaN    NaN       NaN      0.972245
# nr.employed     NaN       NaN       NaN    NaN       NaN      0.906970
#
#                 cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# age                        NaN            NaN        NaN          NaN
# duration                   NaN            NaN        NaN          NaN
# campaign                   NaN            NaN        NaN          NaN
# pdays                      NaN            NaN        NaN          NaN
# previous                   NaN            NaN        NaN          NaN
# emp.var.rate          0.775334            NaN   0.972245     0.906970
# cons.price.idx        1.000000            NaN        NaN          NaN
# cons.conf.idx              NaN            1.0        NaN          NaN
# euribor3m                  NaN            NaN   1.000000     0.945154
# nr.employed                NaN            NaN   0.945154     1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_greater_than_75, cmap="Reds", annot = True);

# %% [markdown]
# > Some correlation can be seen here between emp. var rate and nr.employed.
#
# > Also, euribor3m and emp.var rate.
#
# > However,  I would not be removing any. As I am gonna mostly be training on tree models which doesn't require much preprocessing.

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Checking Unique Values For Days Column</p>

# %%
df['pdays'].unique()
# Out:
# array([999,   6,   4,   3,   5,   1,   0,  10,   7,   8,   9,  11,   2,
#         12,  13,  14,  15,  16,  21,  17,  18,  22,  25,  26,  19,  27,
#         20])

# %% [markdown]
# > **999 represents no contact has been done, thus i'll be assigning it a very less weight.**

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modifying The Columns: Assigning Weight On the Basis Of Importance</p>

# %%
df['job'] = df['job'].apply(lambda x: -1 if x=='unknown' or x=='unemployed' else (15 if x=='entrepreneur' else (8 if x == 'blue-collar' else ( 6 if x=='technician' or x=='services' or  x=='admin.' or x=='management' else (4 if x== 'self-employed' or x=='student' else (2 if x=='housemaid' or x=='retired' else None) )))))
df['housing'] = df['housing'].apply(lambda x: 0 if x=='no' else (1 if x=='yes' else -1))
df['loan'] = df['loan'].apply(lambda x: 0 if x=='no' else (1 if x=='yes' else -1))
df['y'] = df['y'].apply(lambda x: 0 if x=='no' else (1 if x=='yes' else -1))
df['default'] = df['default'].apply(lambda x: 0 if x=='no' else (1 if x=='yes' else -1))
df['poutcome'] = df['poutcome'].apply(lambda x: 0 if x=='failure' else (2 if x=='failure' else -1))
df['pdays'] = df['pdays'].apply(lambda x: 0 if x==999 else(20 if x<=10 else(6 if x<=20 else 3)))

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Dropping Columns Which I Feel Won't Affect The Predictions</p>

# %%
df.drop(['day_of_week', 'contact', 'month'], axis=1, inplace = True)

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">One Hot Encoding Remaining Categorical Features</p>

# %%
df  = pd.get_dummies(df, drop_first = True)

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Train-Test Split</p>

# %%
x = df.drop("y", axis=1)
y = df['y']
x.sample()

x_train,x_test,y_train,y_test = train_test_split(x,y, random_state=42)

# %% [markdown]
# <a id ="5"></a>
#
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Balancing The Data Using Smote</p>

# %%
smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(x_train, y_train)

print('Original dataset shape', len(x_train))
print('Resampled dataset shape', len(x_smote))
# Out:
# Original dataset shape 30891
# Resampled dataset shape 54808

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">For Scaling The Data</p>

# %%
s = StandardScaler()

# %%
(x_train.shape[1])
# Out:
# 25

# %% [markdown]
# <a id ="6"></a>
#
#
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modelling And Optimizing The Models</p>

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modelling With KNN</p>

# %%
knn = KNeighborsClassifier(n_neighbors = 20)
knn.fit( s.fit_transform(x_train), y_train)

classifier(knn, s.fit_transform(x_smote),s.transform(x_test), y_smote,y_test)
# Out:
# Train accuracy is: 0.5832907604729236
# Test accuracy is: 0.9001650966300865
#
# Train ROC is: 0.5832907604729237
# Test ROC is: 0.587934808506699
#
# F score is: 0.2939560439560439
# Precision is: 0.7062706270627063
# Recall is: 0.18560277536860365

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Tuning The Hyperparameterrs Of KNN</p>

# %%
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit( s.fit_transform(x_train), y_train)
 pred_i = knn.predict(s.transform(x_test))
 error_rate.append(np.mean(pred_i != y_test))

acc = []
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(s.fit_transform(x_train), y_train)
    yhat = neigh.predict(s.transform(x_test))
    acc.append(metrics.accuracy_score(y_test, yhat))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.09624162377391474 at K = 10

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# Maximum accuracy:- 0.9037583762260852 at K = 10

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modelling With The Value Of K which Gave Least Error</p>

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit( s.fit_transform(x_smote), y_smote)

classifier(knn, s.fit_transform(x_smote),s.transform(x_test),y_smote,y_test)
# Out:
# Train accuracy is: 0.9329477448547657
# Test accuracy is: 0.8831698552976596
#
# Train ROC is: 0.9329477448547657
# Test ROC is: 0.7075946938224222
#
# F score is: 0.4798962386511024
# Precision is: 0.47844827586206895
# Recall is: 0.4813529921942758

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Bagging With KNN As Base Model</p>

# %%
  
# bagging classifier
model = BaggingClassifier(base_estimator = KNeighborsClassifier(n_neighbors = 10),
                          n_estimators = 15)
classifier(model.fit( s.fit_transform(x_smote), y_smote), s.fit_transform(x_smote),s.transform(x_test),y_smote,y_test)
# Out:
# Train accuracy is: 0.9344986133411181
# Test accuracy is: 0.8802563853549578
#
# Train ROC is: 0.9344986133411181
# Test ROC is: 0.7309663387154662
#
# F score is: 0.5018181818181818
# Precision is: 0.4697428139183056
# Recall is: 0.5385949696444059

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modelling With Decision Tree</p>

# %%
dtree = DecisionTreeClassifier(random_state=0)
dtree.fit(x_train, y_train)
classifier(dtree, x_train,x_test,y_train,y_test)
# Out:
# Train accuracy is: 1.0
# Test accuracy is: 0.8889967951830631
#
# Train ROC is: 1.0
# Test ROC is: 0.7286871556493425
#
# F score is: 0.5129953131657435
# Precision is: 0.5041876046901173
# Recall is: 0.5221162185602776

# %% [markdown]
# **Not using balanced data with tree based models because they can handle imbalace pretty well so whynot.**

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Tuning The Hyperparameters Of Decision Tree</p>

# %%
param_grid = {'max_depth':np.arange(3,20),
              'min_samples_split': np.arange(3,20,1),
             'min_samples_leaf':np.arange(3,30),
              'min_samples_split' : np.arange(3,30),
              'criterion': ('gini', 'entropy')}



random_search(DecisionTreeClassifier(random_state=0),param_grid, x_train,x_test,y_train,y_test)
# Out:
# Best parameters are:  {'min_samples_split': 21, 'min_samples_leaf': 17, 'max_depth': 6, 'criterion': 'entropy'}
#
# Best estimator is:  DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=17,
#                        min_samples_split=21, random_state=0)
#
# Scores and accuracies are:
#
# Train accuracy is: 0.9173545692920269
# Test accuracy is: 0.9172574536272701
#
# Train ROC is: 0.7375454264577269
# Test ROC is: 0.7324721673992832
#
# F score is: 0.572289156626506
# Precision is: 0.6793802145411204
# Recall is: 0.4943625325238508

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Decision Tree Based Bagging</p>

# %%
# I have chosen tuned hyperparameters here


kfold = model_selection.KFold(n_splits = 3)

# bagging classifier
model = BaggingClassifier(base_estimator = DecisionTreeClassifier(min_samples_split=5, min_samples_leaf=25, max_depth=8, criterion='gini'),n_estimators = 500,)

classifier(model.fit(x_train, y_train), x_train,x_test,y_train,y_test)
# Out:
# Train accuracy is: 0.9246382441487812
# Test accuracy is: 0.9212391958822959
#
# Train ROC is: 0.7781927793024171
# Test ROC is: 0.7707162892040924
#
# F score is: 0.621205044371789
# Precision is: 0.6730769230769231
# Recall is: 0.5767562879444926

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Modelling With Random Forest</p>

# %%
rforest = RandomForestClassifier(random_state=0)
classifier(rforest.fit(x_train, y_train), x_train,x_test,y_train,y_test)
# Out:
# Train accuracy is: 0.9999676281117478
# Test accuracy is: 0.914441099349325
#
# Train ROC is: 0.9998566102667049
# Test ROC is: 0.7411186364605551
#
# F score is: 0.5754216867469879
# Precision is: 0.6475054229934925
# Recall is: 0.5177797051170858

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Tuning The HyperParameters Of Random Forest</p>

# %%
params = {'n_estimators' : np.arange(100,1000, 100),
              'max_depth' : np.arange(3,20,1),
              'min_samples_split' : np.arange(3,20,1),
              'min_samples_leaf' : np.arange(3,20,1),
         'max_features': ('sqrt', 'log2'), 'criterion': ('gini', 'entropy')}

random_search(RandomForestClassifier(random_state=0),params, x_train,x_test,y_train,y_test)
# Out:
# Best parameters are:  {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'max_depth': 17, 'criterion': 'entropy'}
#
# Best estimator is:  RandomForestClassifier(criterion='entropy', max_depth=17, max_features='sqrt',
#                        min_samples_leaf=13, min_samples_split=10,
#                        random_state=0)
#
# Scores and accuracies are:
#
# Train accuracy is: 0.9305622996989414
# Test accuracy is: 0.915897834320676
#
# Train ROC is: 0.7511216620550748
# Test ROC is: 0.7051786905322871
#
# F score is: 0.5359056806002144
# Precision is: 0.7012622720897616
# Recall is: 0.4336513443191674

# %% [markdown]
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Using ANN</p>

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = x_train.shape[1]))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
model_history=classifier.fit(s.fit_transform(x_smote), y_smote,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# 2021-12-30 12:26:05.683805: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-30 12:26:05.684381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.685434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-12-30 12:26:05.685631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-30 12:26:05.685703: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-30 12:26:05.685745: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-30 12:26:05.685780: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-30 12:26:05.685824: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-30 12:26:05.685867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-30 12:26:05.685905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-30 12:26:05.685950: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-30 12:26:05.686137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.687138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.687994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-30 12:26:05.690154: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-30 12:26:05.690356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.690915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-12-30 12:26:05.690970: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-30 12:26:05.690995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-30 12:26:05.691014: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-30 12:26:05.691056: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-30 12:26:05.691086: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-30 12:26:05.691106: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-30 12:26:05.691125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-30 12:26:05.691143: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-30 12:26:05.691224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.691837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.692382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-30 12:26:05.692458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-30 12:26:05.692468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-12-30 12:26:05.692476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-12-30 12:26:05.692622: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.693247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-30 12:26:05.693785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2021-12-30 12:26:06.120512: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-12-30 12:26:06.130407: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000140000 Hz
# Epoch 1/100
# 2021-12-30 12:26:06.554334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
#   48/3673 [..............................] - ETA: 7s - loss: 1.5570 - accuracy: 0.2395
# 2021-12-30 12:26:07.287415: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 3673/3673 [==============================] - 12s 3ms/step - loss: 0.8012 - accuracy: 0.5751 - val_loss: 0.6912 - val_accuracy: 0.5748
# Epoch 2/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.3534 - accuracy: 0.8624 - val_loss: 0.3620 - val_accuracy: 0.8431
# Epoch 3/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2692 - accuracy: 0.8843 - val_loss: 0.2977 - val_accuracy: 0.8830
# Epoch 4/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2475 - accuracy: 0.8928 - val_loss: 0.2786 - val_accuracy: 0.8946
# Epoch 5/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2399 - accuracy: 0.8949 - val_loss: 0.2859 - val_accuracy: 0.8939
# Epoch 6/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2349 - accuracy: 0.8958 - val_loss: 0.2556 - val_accuracy: 0.9104
# Epoch 7/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2306 - accuracy: 0.8972 - val_loss: 0.2508 - val_accuracy: 0.9108
# Epoch 8/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2311 - accuracy: 0.8963 - val_loss: 0.2472 - val_accuracy: 0.9097
# Epoch 9/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2248 - accuracy: 0.8986 - val_loss: 0.2553 - val_accuracy: 0.9066
# Epoch 10/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2199 - accuracy: 0.9004 - val_loss: 0.2331 - val_accuracy: 0.9171
# Epoch 11/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2277 - accuracy: 0.8978 - val_loss: 0.2407 - val_accuracy: 0.9123
# Epoch 12/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2196 - accuracy: 0.9000 - val_loss: 0.2522 - val_accuracy: 0.9055
# Epoch 13/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2186 - accuracy: 0.9024 - val_loss: 0.2304 - val_accuracy: 0.9165
# Epoch 14/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2201 - accuracy: 0.9019 - val_loss: 0.2350 - val_accuracy: 0.9119
# Epoch 15/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2152 - accuracy: 0.9029 - val_loss: 0.2255 - val_accuracy: 0.9165
# Epoch 16/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2150 - accuracy: 0.9010 - val_loss: 0.2315 - val_accuracy: 0.9125
# Epoch 17/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2132 - accuracy: 0.9022 - val_loss: 0.2220 - val_accuracy: 0.9170
# Epoch 18/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2100 - accuracy: 0.9038 - val_loss: 0.2113 - val_accuracy: 0.9215
# Epoch 19/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2186 - accuracy: 0.9006 - val_loss: 0.2266 - val_accuracy: 0.9129
# Epoch 20/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2177 - accuracy: 0.9014 - val_loss: 0.2045 - val_accuracy: 0.9265
# Epoch 21/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2154 - accuracy: 0.9026 - val_loss: 0.2071 - val_accuracy: 0.9248
# Epoch 22/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2182 - accuracy: 0.9009 - val_loss: 0.2157 - val_accuracy: 0.9185
# Epoch 23/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2142 - accuracy: 0.9022 - val_loss: 0.2050 - val_accuracy: 0.9241
# Epoch 24/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2167 - accuracy: 0.9010 - val_loss: 0.2187 - val_accuracy: 0.9158
# Epoch 25/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2152 - accuracy: 0.9025 - val_loss: 0.2116 - val_accuracy: 0.9192
# Epoch 26/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2125 - accuracy: 0.9026 - val_loss: 0.2195 - val_accuracy: 0.9165
# Epoch 27/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2147 - accuracy: 0.9030 - val_loss: 0.2156 - val_accuracy: 0.9175
# Epoch 28/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2060 - accuracy: 0.9076 - val_loss: 0.2246 - val_accuracy: 0.9124
# Epoch 29/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2128 - accuracy: 0.9043 - val_loss: 0.2118 - val_accuracy: 0.9194
# Epoch 30/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2155 - accuracy: 0.9009 - val_loss: 0.2125 - val_accuracy: 0.9189
# Epoch 31/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2131 - accuracy: 0.9036 - val_loss: 0.2024 - val_accuracy: 0.9245
# Epoch 32/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2082 - accuracy: 0.9050 - val_loss: 0.2136 - val_accuracy: 0.9187
# Epoch 33/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2120 - accuracy: 0.9042 - val_loss: 0.2122 - val_accuracy: 0.9192
# Epoch 34/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2136 - accuracy: 0.9045 - val_loss: 0.2243 - val_accuracy: 0.9120
# Epoch 35/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2093 - accuracy: 0.9047 - val_loss: 0.2018 - val_accuracy: 0.9243
# Epoch 36/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2100 - accuracy: 0.9049 - val_loss: 0.2185 - val_accuracy: 0.9154
# Epoch 37/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2092 - accuracy: 0.9039 - val_loss: 0.2079 - val_accuracy: 0.9207
# Epoch 38/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2077 - accuracy: 0.9063 - val_loss: 0.2049 - val_accuracy: 0.9220
# Epoch 39/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2131 - accuracy: 0.9040 - val_loss: 0.1969 - val_accuracy: 0.9273
# Epoch 40/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2130 - accuracy: 0.9035 - val_loss: 0.2195 - val_accuracy: 0.9150
# Epoch 41/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2074 - accuracy: 0.9059 - val_loss: 0.2182 - val_accuracy: 0.9148
# Epoch 42/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2125 - accuracy: 0.9027 - val_loss: 0.2076 - val_accuracy: 0.9211
# Epoch 43/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2120 - accuracy: 0.9040 - val_loss: 0.1985 - val_accuracy: 0.9261
# Epoch 44/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2100 - accuracy: 0.9059 - val_loss: 0.2105 - val_accuracy: 0.9202
# Epoch 45/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2091 - accuracy: 0.9064 - val_loss: 0.2005 - val_accuracy: 0.9241
# Epoch 46/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2059 - accuracy: 0.9063 - val_loss: 0.2136 - val_accuracy: 0.9183
# Epoch 47/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2096 - accuracy: 0.9051 - val_loss: 0.2128 - val_accuracy: 0.9197
# Epoch 48/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2115 - accuracy: 0.9033 - val_loss: 0.2086 - val_accuracy: 0.9214
# Epoch 49/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2122 - accuracy: 0.9026 - val_loss: 0.2004 - val_accuracy: 0.9251
# Epoch 50/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2072 - accuracy: 0.9056 - val_loss: 0.1950 - val_accuracy: 0.9265
# Epoch 51/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2097 - accuracy: 0.9039 - val_loss: 0.2080 - val_accuracy: 0.9206
# Epoch 52/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2042 - accuracy: 0.9065 - val_loss: 0.2081 - val_accuracy: 0.9208
# Epoch 53/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2084 - accuracy: 0.9059 - val_loss: 0.1955 - val_accuracy: 0.9264
# Epoch 54/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2113 - accuracy: 0.9034 - val_loss: 0.2075 - val_accuracy: 0.9200
# Epoch 55/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2108 - accuracy: 0.9043 - val_loss: 0.2045 - val_accuracy: 0.9222
# Epoch 56/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2090 - accuracy: 0.9054 - val_loss: 0.2033 - val_accuracy: 0.9222
# Epoch 57/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2073 - accuracy: 0.9055 - val_loss: 0.2097 - val_accuracy: 0.9198
# Epoch 58/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2089 - accuracy: 0.9049 - val_loss: 0.2059 - val_accuracy: 0.9203
# Epoch 59/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2090 - accuracy: 0.9056 - val_loss: 0.2027 - val_accuracy: 0.9230
# Epoch 60/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2042 - accuracy: 0.9079 - val_loss: 0.2015 - val_accuracy: 0.9246
# Epoch 61/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2022 - accuracy: 0.9105 - val_loss: 0.2175 - val_accuracy: 0.9158
# Epoch 62/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2043 - accuracy: 0.9061 - val_loss: 0.2067 - val_accuracy: 0.9214
# Epoch 63/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2065 - accuracy: 0.9066 - val_loss: 0.2038 - val_accuracy: 0.9207
# Epoch 64/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2081 - accuracy: 0.9052 - val_loss: 0.1997 - val_accuracy: 0.9245
# Epoch 65/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2106 - accuracy: 0.9043 - val_loss: 0.1971 - val_accuracy: 0.9255
# Epoch 66/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2034 - accuracy: 0.9075 - val_loss: 0.2034 - val_accuracy: 0.9220
# Epoch 67/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2091 - accuracy: 0.9035 - val_loss: 0.2041 - val_accuracy: 0.9226
# Epoch 68/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2029 - accuracy: 0.9089 - val_loss: 0.2000 - val_accuracy: 0.9248
# Epoch 69/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2063 - accuracy: 0.9059 - val_loss: 0.2008 - val_accuracy: 0.9241
# Epoch 70/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2074 - accuracy: 0.9073 - val_loss: 0.2036 - val_accuracy: 0.9234
# Epoch 71/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2081 - accuracy: 0.9046 - val_loss: 0.1976 - val_accuracy: 0.9261
# Epoch 72/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2010 - accuracy: 0.9106 - val_loss: 0.1858 - val_accuracy: 0.9332
# Epoch 73/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2033 - accuracy: 0.9074 - val_loss: 0.2027 - val_accuracy: 0.9228
# Epoch 74/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2030 - accuracy: 0.9080 - val_loss: 0.1920 - val_accuracy: 0.9292
# Epoch 75/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2082 - accuracy: 0.9062 - val_loss: 0.2054 - val_accuracy: 0.9204
# Epoch 76/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2044 - accuracy: 0.9077 - val_loss: 0.1986 - val_accuracy: 0.9250
# Epoch 77/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2063 - accuracy: 0.9065 - val_loss: 0.2005 - val_accuracy: 0.9238
# Epoch 78/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2049 - accuracy: 0.9081 - val_loss: 0.2080 - val_accuracy: 0.9176
# Epoch 79/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2050 - accuracy: 0.9093 - val_loss: 0.1923 - val_accuracy: 0.9275
# Epoch 80/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2012 - accuracy: 0.9080 - val_loss: 0.1953 - val_accuracy: 0.9267
# Epoch 81/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2075 - accuracy: 0.9062 - val_loss: 0.2028 - val_accuracy: 0.9218
# Epoch 82/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2069 - accuracy: 0.9066 - val_loss: 0.2002 - val_accuracy: 0.9244
# Epoch 83/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2016 - accuracy: 0.9088 - val_loss: 0.1963 - val_accuracy: 0.9270
# Epoch 84/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2047 - accuracy: 0.9072 - val_loss: 0.1831 - val_accuracy: 0.9339
# Epoch 85/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2045 - accuracy: 0.9087 - val_loss: 0.1954 - val_accuracy: 0.9270
# Epoch 86/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2034 - accuracy: 0.9087 - val_loss: 0.2006 - val_accuracy: 0.9244
# Epoch 87/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2041 - accuracy: 0.9078 - val_loss: 0.1905 - val_accuracy: 0.9298
# Epoch 88/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2040 - accuracy: 0.9084 - val_loss: 0.2078 - val_accuracy: 0.9213
# Epoch 89/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2021 - accuracy: 0.9085 - val_loss: 0.1919 - val_accuracy: 0.9287
# Epoch 90/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2042 - accuracy: 0.9073 - val_loss: 0.1884 - val_accuracy: 0.9306
# Epoch 91/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2004 - accuracy: 0.9096 - val_loss: 0.1979 - val_accuracy: 0.9244
# Epoch 92/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.1999 - accuracy: 0.9088 - val_loss: 0.2068 - val_accuracy: 0.9203
# Epoch 93/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2067 - accuracy: 0.9056 - val_loss: 0.1942 - val_accuracy: 0.9263
# Epoch 94/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2044 - accuracy: 0.9066 - val_loss: 0.1978 - val_accuracy: 0.9249
# Epoch 95/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2010 - accuracy: 0.9079 - val_loss: 0.1983 - val_accuracy: 0.9247
# Epoch 96/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2011 - accuracy: 0.9062 - val_loss: 0.1924 - val_accuracy: 0.9263
# Epoch 97/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2061 - accuracy: 0.9083 - val_loss: 0.1984 - val_accuracy: 0.9240
# Epoch 98/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2042 - accuracy: 0.9081 - val_loss: 0.1888 - val_accuracy: 0.9281
# Epoch 99/100
# 3673/3673 [==============================] - 11s 3ms/step - loss: 0.2006 - accuracy: 0.9082 - val_loss: 0.1956 - val_accuracy: 0.9243
# Epoch 100/100
# 3673/3673 [==============================] - 10s 3ms/step - loss: 0.2019 - accuracy: 0.9087 - val_loss: 0.1865 - val_accuracy: 0.9296

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model accuracy Vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss Vs Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# <a id ="8"></a>
#
#
# # <p style="background-color:#FA8072;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:40px 40px;">Results & Conclusion</p>
#
# > **Bagging with Decision tree is performing the best according to recall and roc.**
#
# > **For a credit insurance problem, I would want to go with recall here.**
